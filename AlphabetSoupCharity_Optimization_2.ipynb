# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN","NAME"],inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type = application_df["APPLICATION_TYPE"].value_counts()
application_type
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = application_type.loc[lambda x: x < 528].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_ct = application_df['CLASSIFICATION'].value_counts()
classification_ct
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classification_ct.loc[lambda x: x <100].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
cat_to_num_df = pd.get_dummies(application_df)
cat_to_num_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 50 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STATUS                        34299 non-null  int64
#  1   ASK_AMT                       34299 non-null  int64
#  2   IS_SUCCESSFUL                 34299 non-null  int64
#  3   APPLICATION_TYPE_Other        34299 non-null  uint8
#  4   APPLICATION_TYPE_T10          34299 non-null  uint8
#  5   APPLICATION_TYPE_T19          34299 non-null  uint8
#  6   APPLICATION_TYPE_T3           34299 non-null  uint8
#  7   APPLICATION_TYPE_T4           34299 non-null  uint8
#  8   APPLICATION_TYPE_T5           34299 non-null  uint8
#  9   APPLICATION_TYPE_T6           34299 non-null  uint8
#  10  APPLICATION_TYPE_T7           34299 non-null  uint8
#  11  APPLICATION_TYPE_T8           34299 non-null  uint8
#  12  AFFILIATION_CompanySponsored  34299 non-null  uint8
#  13  AFFILIATION_Family/Parent     34299 non-null  uint8
#  14  AFFILIATION_Independent       34299 non-null  uint8
#  15  AFFILIATION_National          34299 non-null  uint8
#  16  AFFILIATION_Other             34299 non-null  uint8
#  17  AFFILIATION_Regional          34299 non-null  uint8
#  18  CLASSIFICATION_C1000          34299 non-null  uint8
#  19  CLASSIFICATION_C1200          34299 non-null  uint8
#  20  CLASSIFICATION_C1270          34299 non-null  uint8
#  21  CLASSIFICATION_C1700          34299 non-null  uint8
#  22  CLASSIFICATION_C2000          34299 non-null  uint8
#  23  CLASSIFICATION_C2100          34299 non-null  uint8
#  24  CLASSIFICATION_C2700          34299 non-null  uint8
#  25  CLASSIFICATION_C3000          34299 non-null  uint8
#  26  CLASSIFICATION_C4000          34299 non-null  uint8
#  27  CLASSIFICATION_C5000          34299 non-null  uint8
#  28  CLASSIFICATION_C7000          34299 non-null  uint8
#  29  CLASSIFICATION_Other          34299 non-null  uint8
#  30  USE_CASE_CommunityServ        34299 non-null  uint8
#  31  USE_CASE_Heathcare            34299 non-null  uint8
#  32  USE_CASE_Other                34299 non-null  uint8
#  33  USE_CASE_Preservation         34299 non-null  uint8
#  34  USE_CASE_ProductDev           34299 non-null  uint8
#  35  ORGANIZATION_Association      34299 non-null  uint8
#  36  ORGANIZATION_Co-operative     34299 non-null  uint8
#  37  ORGANIZATION_Corporation      34299 non-null  uint8
#  38  ORGANIZATION_Trust            34299 non-null  uint8
#  39  INCOME_AMT_0                  34299 non-null  uint8
#  40  INCOME_AMT_1-9999             34299 non-null  uint8
#  41  INCOME_AMT_10000-24999        34299 non-null  uint8
#  42  INCOME_AMT_100000-499999      34299 non-null  uint8
#  43  INCOME_AMT_10M-50M            34299 non-null  uint8
#  44  INCOME_AMT_1M-5M              34299 non-null  uint8
#  45  INCOME_AMT_25000-99999        34299 non-null  uint8
#  46  INCOME_AMT_50M+               34299 non-null  uint8
#  47  INCOME_AMT_5M-10M             34299 non-null  uint8
#  48  SPECIAL_CONSIDERATIONS_N      34299 non-null  uint8
#  49  SPECIAL_CONSIDERATIONS_Y      34299 non-null  uint8
# dtypes: int64(3), uint8(47)
# memory usage: 2.3 MB

# %%
# Split our preprocessed data into our features and target arrays
y = cat_to_num_df["IS_SUCCESSFUL"]
X = cat_to_num_df.drop(columns="IS_SUCCESSFUL")
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=49,activation="relu",input_dim=49))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=33,activation="relu"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=14,activation="relu"))

# Fourth hidden layer
nn_model.add(tf.keras.layers.Dense(units=21,activation="relu"))

# Fifth hidden layer
nn_model.add(tf.keras.layers.Dense(units=7,activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 49)                2450
#
#  dense_1 (Dense)             (None, 33)                1650
#
#  dense_2 (Dense)             (None, 14)                476
#
#  dense_3 (Dense)             (None, 21)                315
#
#  dense_4 (Dense)             (None, 7)                 154
#
#  dense_5 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 5,053
# Trainable params: 5,053
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
# Train the model
nn_model.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 10s 6ms/step - loss: 0.5748 - accuracy: 0.7138
# Epoch 2/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5554 - accuracy: 0.7264
# Epoch 3/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5525 - accuracy: 0.7284
# Epoch 4/50
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5491 - accuracy: 0.7313
# Epoch 5/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5484 - accuracy: 0.7321
# Epoch 6/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5465 - accuracy: 0.7326
# Epoch 7/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7325
# Epoch 8/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5452 - accuracy: 0.7332
# Epoch 9/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7334
# Epoch 10/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7343
# Epoch 11/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7331
# Epoch 12/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7349
# Epoch 13/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7351
# Epoch 14/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7353
# Epoch 15/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5422 - accuracy: 0.7353
# Epoch 16/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7354
# Epoch 17/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7349
# Epoch 18/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7364
# Epoch 19/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7354
# Epoch 20/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7370
# Epoch 21/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5399 - accuracy: 0.7366
# Epoch 22/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7375
# Epoch 23/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7344
# Epoch 24/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7375
# Epoch 25/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7371
# Epoch 26/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7379
# Epoch 27/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7378
# Epoch 28/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5386 - accuracy: 0.7377
# Epoch 29/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5378 - accuracy: 0.7378
# Epoch 30/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7384
# Epoch 31/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7380
# Epoch 32/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7381
# Epoch 33/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7372
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7372
# Epoch 35/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5366 - accuracy: 0.7380
# Epoch 36/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5365 - accuracy: 0.7390
# Epoch 37/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7377
# Epoch 38/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7373
# Epoch 39/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5360 - accuracy: 0.7381
# Epoch 40/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7380
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7383
# Epoch 42/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5354 - accuracy: 0.7384
# Epoch 43/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5353 - accuracy: 0.7384
# Epoch 44/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5353 - accuracy: 0.7390
# Epoch 45/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7387
# Epoch 46/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7393
# Epoch 47/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7399
# Epoch 48/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5352 - accuracy: 0.7393
# Epoch 49/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5348 - accuracy: 0.7390
# Epoch 50/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7388

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5518 - accuracy: 0.7230 - 557ms/epoch - 2ms/step
# Loss: 0.5517654418945312, Accuracy: 0.7230320572853088

# %%
# Export our model to HDF5 file
nn_model.save("AlphabetSoupCharity_2.h5")
